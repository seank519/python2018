# %%
#우리 지역이 안전한 지역인지, 각 지역별 범죄 발생건수 그래프 만드는 파이썬
import csv
f=open('범죄발생지_2016년_시도별합계데이터.csv')
csv_data=csv.reader(f)
crime_area = []
crime_count = []
first_line = 1
total_sum = 0
count = 0
for line in csv_data:
    for data in line:
        if first_line:
            crime_area.append(data)
        else:
            crime_count.append(int(data))
            total_sum += int(data)
            count += 1
    first_line = 0    
f.close()

average = total_sum / count

loop = True
while loop:
    print("예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력")
    in_area = input('살고있는 지역을 입력해주세요 :')
    if in_area in crime_area:
        loop = False

    if loop:
        print("잘못 입력하셨습니다. 다시 입력해 주세요.")
    else:
        i = crime_area.index(in_area)
        if crime_count[i] >= average:
            print(in_area+"은(는) 범죄로부터 비교적 위험한 지역입니다")
        else:
            print(in_area+"은(는) 범죄로부터 비교적 안전한 지역입니다")

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6), dpi=100)
plt.rc('font', family = 'Malgun Gothic')
plt.bar(crime_area,crime_count)
plt.title('2016년도 시도별 총 범죄발생 건수')
plt.xlabel('지역')
plt.ylabel('발생건수')
plt.grid()
plt.show()
# Out:
# 예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력
# 살고있는 지역을 입력해주세요 :서울
# 서울은(는) 범죄로부터 비교적 위험한 지역입니다

# %%
#각 지역의 범죄 종류별로 범죄 수를 알려주는 파이썬
print("예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력")
a=input('범죄 건수를 알고 싶은 지역을 입력해주세요 : ')
print("예:살인기수,살인미수등,강도,강간,유사강간,강제추행,기타 강간 강제추행등,방화,절도범죄,상해,폭행,체포 감금,협박,약취 유인,폭력행위등,공갈,손괴,직무유기,직권남용,증수뢰,통화,문서 인장,유가증권인지,사기,횡령,배임,성풍속범죄,도박범죄,특별경제범죄,마약범죄,보건범죄,환경범죄,교통범죄,노동범죄,안보범죄,선거범죄,병역범죄,기타범죄")
b=input('어떤 범죄에 대해서 알고 싶나요? ')

import csv
f=open('범죄발생지_2016년_시도별.csv')
csv_data=csv.reader(f)
next(csv_data)
csv_data = list(csv_data)
crime_area = []
e = []
first_line = 1
for line in csv_data:
    for data in line:
        if first_line:
            crime_area.append(data)

cnt = 0
menu = ['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주','기타']
for i in range(len(menu)) :
    if menu[i] == a :
        cnt = i
cnt2 = 0
menu2 = ['살인기수','살인미수등','강도','강간','유사강간','강제추행','기타 강간 강제추행등','방화','절도범죄','상해','폭행','체포 감금','협박','약취 유인','폭력행위등','공갈','손괴','직무유기','직권남용','증수뢰','통화','문서 인장','유가증권인지','사기','횡령','배임','성풍속범죄','도박범죄','특별경제범죄','마약범죄','보건범죄','환경범죄','교통범죄','노동범죄','안보범죄','선거범죄','병역범죄','기타범죄']
for k in range(len(menu)) :
    if menu2[k] == b :
        cnt2 = k
for row in csv_data :
    e.append(row[cnt])
print(a+" 지역의 "+b+" 발생건수는 ", int(e[cnt2]), "건 입니다.")
f.close()
# Out:
# 예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력
# 범죄 건수를 알고 싶은 지역을 입력해주세요대전
# 예:살인기수,살인미수등,강도,강간,유사강간,강제추행,기타 강간 강제추행등,방화,절도범죄,상해,폭행,체포 감금,협박,약취 유인,폭력행위등,공갈,손괴,직무유기,직권남용,증수뢰,통화,문서 인장,유가증권인지,사기,횡령,배임,성풍속범죄,도박범죄,특별경제범죄,마약범죄,보건범죄,환경범죄,교통범죄,노동범죄,안보범죄,선거범죄,병역범죄,기타범죄
# 어떤 범죄에 대해서 알고 싶나요?안보범죄
# 대전 지역의 안보범죄 발생건수는  16 건 입니다.

# %%
#각 범죄의 비율을 알려주는 원그래프
import csv
f=open('범죄발생지_2016년_주요도시1.csv')
data = csv.reader(f)
next(data)

crime_name = ['강력범죄', '절도범죄', '폭력범죄', '지능범죄', '풍속범죄', '특별경제범죄', '마약범죄','보건범죄', '환경범죄','교통범죄','노동범죄','안보범죄','선거범죄','병역범죄','기타범죄']
result = []
crime_list = []

for row in data :
    if row[0] in crime_name :
        sig=0
        for i in range(2,20):
            sig += int(row[i])

        if row[0] in crime_list :
            i = crime_list.index(row[0])     
            result[i] += sig
        else : 
            crime_list.append(row[0])
            result.append(sig)   

print(crime_list)    
print(result)    

import matplotlib.pyplot as plt
plt.figure(figsize=(15,15), dpi=300)
plt.rc('font', family= 'Malgun Gothic')
plt.title('2016년도 각종 범죄의 비율')
plt.pie(result, labels=crime_list)
#plt.savefig('2016년도 각종 범죄의 비율.png')
plt.show()
# Out:
# ['강력범죄', '절도범죄', '폭력범죄', '지능범죄', '풍속범죄', '특별경제범죄', '마약범죄', '보건범죄', '환경범죄', '교통범죄', '노동범죄', '안보범죄', '선거범죄', '병역범죄', '기타범죄']
# [25461, 201036, 304687, 309173, 25983, 64511, 7291, 14454, 4265, 590712, 2441, 80, 998, 16538, 256998]

# %%
#이전 버전
import csv
f=open('범죄발생지_2016년_주요도시1.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[0] == '강력범죄':
        sig=0
        for i in range(2,20):
                sig=sig+int(row[i])            
        result.append(sig)
    if row[0] == '절도범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)    

    if row[0] == '폭력범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)     
        
    if row[0] == '지능범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)     
        
    if row[0] == '풍속범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)     
        
    if row[0] == '특별경제범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)     
    if row[0] == '마약범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)     
    if row[0] == '보건범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)   
    if row[0] == '환경범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)       
    if row[0] == '교통범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)   
    if row[0] == '노동범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)       
    if row[0] == '안보범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)
    if row[0] == '선거범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)    
    if row[0] == '병역범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)    
    if row[0] == '기타범죄':
        sig=0    
        for i in range(2,20):
                sig=sig+int(row[i])
        result.append(sig)    
        
        
        
print(result)    
import matplotlib.pyplot as plt
plt.pie(result)
plt.show()
# Out:
# [356, 551, 1132, 5067, 570, 15903, 402, 1480, 201036, 48713, 163862, 1300, 15652, 197, 13121, 3700, 58142, 523, 434, 254, 1804, 13109, 219, 238913, 49636, 4281, 12631, 13352, 64511, 7291, 14454, 4265, 590712, 2441, 80, 998, 16538, 256998]

# %%
#각 지역의 범죄 종류별로 범죄 수를 알려주고, 그 지역의 범죄의 비율을 알려주는 원그래프
import csv
f=open('범죄발생지_2016년_주요도시1.csv')
data = csv.reader(f)

crime_name = ['강력범죄', '절도범죄', '폭력범죄', '지능범죄', '풍속범죄', '특별경제범죄', '마약범죄','보건범죄', '환경범죄','교통범죄','노동범죄','안보범죄','선거범죄','병역범죄','기타범죄']
result = []
crime_list = []
crime_area = []

for row in data :
    for sido in row:
        crime_area.append(sido)
    break

loop = True
area_pos = 0
while loop:
    print("예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력")
    in_area=input('범죄 건수를 알고 싶은 지역을 입력해주세요 : ')
    if in_area in crime_area :
        loop = False
    if loop:
        print("잘못 입력하셨습니다. 다시 입력해 주세요.")
    else:
        area_pos = crime_area.index(in_area)

loop = True
crime_pos = 0
while loop:
    print("예:강력범죄, 절도범죄, 폭력범죄, 지능범죄, 풍속범죄, 특별경제범죄, 마약범죄, 보건범죄, 환경범죄, 교통범죄, 노동범죄, 안보범죄, 선거범죄, 병역범죄, 기타범죄")
    in_crime=input('어떤 범죄에 대해서 알고 싶나요? ')
    if in_crime in crime_name :
        loop = False
    if loop:
        print("잘못 입력하셨습니다. 다시 입력해 주세요.")
    else:
        crime_pos = crime_name.index(in_crime)

for row in data :
    if row[0] in crime_name :
        sig = int(row[area_pos])

        if row[0] in crime_list :
            i = crime_list.index(row[0])
            result[i] += sig
        else : 
            crime_list.append(row[0])
            result.append(sig)   
    
print(in_area+" 지역의 "+in_crime+" 발생건수는 ", int(result[crime_pos]), "건 입니다.")

import matplotlib.pyplot as plt
plt.figure(figsize=(15,15), dpi=300)
plt.rc('font', family= 'Malgun Gothic')
plt.title('2016년도 '+in_area+' 지역의 각종 범죄의 비율')
plt.pie(result, labels=crime_list)
plt.show()
# Out:
# 예:서울,부산,대구,인천,광주,대전,울산,세종,경기,강원,충북,충남,전북,전남,경북,경남,제주,기타 중 한곳 입력
# 범죄 건수를 알고 싶은 지역을 입력해주세요 : 서울
# 예:강력범죄, 절도범죄, 폭력범죄, 지능범죄, 풍속범죄, 특별경제범죄, 마약범죄, 보건범죄, 환경범죄, 교통범죄, 노동범죄, 안보범죄, 선거범죄, 병역범죄, 기타범죄
# 어떤 범죄에 대해서 알고 싶나요? 절도범죄
# 서울 지역의 절도범죄 발생건수는  46861 건 입니다.
